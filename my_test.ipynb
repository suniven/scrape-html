# %%
import pandas as pd

df=pd.read_feather('./all-URL-no-filters.feather')

# %%
df
# Out:
#                                              comment_text         author_name  \
# 0       এইটা আমাদের ফ্রি কোর্স  ( CPA Marketing full r...  Mehedi Hasan Zihad
# 1       Apply Now ( CPA Marketing full road)\r\nRegist...  Mehedi Hasan Zihad
# 2       রেজিস্ট্রেশন লিংক  - https://mhzacademy.com/cp...  Mehedi Hasan Zihad
# 3       https://youtu.be/Sew4rctKghY\nI would love you...        Dalton Bumpy
# 4       AP!!!! Another Blazin Study by the Prophets of...  MICHAEL BEN ISRAEL
# ...                                                   ...                 ...
# 308575  Think both of you would enjoy this video:\nhtt...  Innocent Bystander
# 308576  Links Below 👇🏻\nDress (Similar): https://bit.l...     Brittany Xavier
# 308577  Links below to outfits we wore 💞\nTan Top (Sim...     Brittany Xavier
# 308578  LINKS to all the items mentioned in the video!...     Brittany Xavier
# 308579  Shop outfits I wore below 💞\nSkirt: https://bi...     Brittany Xavier
#
# ...

# %%
urls=df.iloc[:,-1].values

# %%
urls
# Out:
# array([array(['https://mhzacademy.spayee.com/s/store'], dtype=object),
#        array(['https://forms.gle/T2eexAjR3ypK9DYW8'], dtype=object),
#        array(['https://mhzacademy.com/cpa-marketing-roadmap/'], dtype=object),
#        ..., array(['https://bit.ly/3nY3dBt', 'https://bit.ly/3nYABYO',
#                    'https://bit.ly/3uOtje7', 'https://bit.ly/3uKg1zq',
#                    'https://bit.ly/3P8iEmA', 'https://bit.ly/3PmZWYf',
#                    'https://bit.ly/3aA1BLn', 'https://bit.ly/3z52KEg',
#                    'https://bit.ly/3P9BkTg', 'https://bit.ly/3P7Sctx',
#                    'https://bit.ly/3z3yjy5'], dtype=object)           ,
#        array(['https://bit.ly/3AbDe0X', 'https://bit.ly/3ueQpdM',
#               'https://bit.ly/3QQKqW2', 'https://bit.ly/3Nq6CDH',
#               'https://bit.ly/3a2QM49', 'https://bit.ly/3nshHtg',
#               'https://bit.ly/3y49Red', 'https://bit.ly/3bD05s1',
# ...

# %%
result=[]
no=[]
for url_list in urls:
    for url in url_list:
        if url.startswith('http://') or url.startswith('https://'):
            result.append(url)
        else:
            no.append(url)

# %%
result
# Out:
# ['https://mhzacademy.spayee.com/s/store',
#  'https://forms.gle/T2eexAjR3ypK9DYW8',
#  'https://mhzacademy.com/cpa-marketing-roadmap/',
#  'https://youtu.be/Sew4rctKghY',
#  'http://originalroyalty.com/product/aviyah-dreaming-zion-cd-copy/',
#  'http://originalroyalty.com/product/solomon-the-jew-transgression-cd/',
#  'http://originalroyalty.com/product/aviyah-dreaming-zion-cd-copy/',
#  'http://originalroyalty.com/product/solomon-the-jew-transgression-cd/',
#  'http://originalroyalty.com/product/aviyah-dreaming-zion-cd-copy/',
#  'http://originalroyalty.com/product/solomon-the-jew-transgression-cd/',
#  'http://originalroyalty.com/product/aviyah-dreaming-zion-cd-copy/',
#  'http://originalroyalty.com/product/solomon-the-jew-transgression-cd/',
#  'http://originalroyalty.com/product/aviyah-dreaming-zion-cd-copy/',
#  'http://originalroyalty.com/product/solomon-the-jew-transgression-cd/',
#  'http://originalroyalty.com/product/aviyah-dreaming-zion-cd-copy/',
# ...

# %%
output=pd.DataFrame(data=result, columns=['url'])
no_df=pd.DataFrame(data=no, columns=['url'])

# %%
output
# Out:
#                                                       url
# 0                   https://mhzacademy.spayee.com/s/store
# 1                     https://forms.gle/T2eexAjR3ypK9DYW8
# 2           https://mhzacademy.com/cpa-marketing-roadmap/
# 3                            https://youtu.be/Sew4rctKghY
# 4       http://originalroyalty.com/product/aviyah-drea...
# ...                                                   ...
# 445844                             https://bit.ly/3ya1bDl
# 445845                             https://bit.ly/3ncX5oL
# 445846                             https://bit.ly/3NcsBxz
# 445847                             https://bit.ly/3Ni8IVO
# 445848                             https://bit.ly/3tZNWUp
#
# [445849 rows x 1 columns]

# %%
no_df
# Out:
#                                      url
# 0                                   http
# 1                                  https
# 5                                  http,
# 6                                 https.
# 10            http_build_query($_POST));
# ...                                  ...
# 1221       https:/v/youtu.be/ft_8knDiJxA
# 1223                       http/Fue/pass
# 1224                               http/
# 1225  http//Facebook//drotukeherbalhome:
# 1236                             https:.
#
# [147 rows x 1 columns]

# %%
output=output.drop_duplicates()
no_df=no_df.drop_duplicates()

# %%
output
# Out:
#                                                       url
# 0                   https://mhzacademy.spayee.com/s/store
# 1                     https://forms.gle/T2eexAjR3ypK9DYW8
# 2           https://mhzacademy.com/cpa-marketing-roadmap/
# 3                            https://youtu.be/Sew4rctKghY
# 4       http://originalroyalty.com/product/aviyah-drea...
# ...                                                   ...
# 445844                             https://bit.ly/3ya1bDl
# 445845                             https://bit.ly/3ncX5oL
# 445846                             https://bit.ly/3NcsBxz
# 445847                             https://bit.ly/3Ni8IVO
# 445848                             https://bit.ly/3tZNWUp
#
# [185745 rows x 1 columns]

# %%
output.to_csv('./youtube-all-urls.csv', index = False)
no_df.to_csv('./no.csv', index = False)

# %%
output=output.reindex(columns=output.columns.tolist() + ["domain"])
count=output.shape[0]
for i in range(count):
    output.iloc[i, 1] = '.'.join(output.iloc[i, 0].split('/')[2].split('.')[-2:])
output.to_csv('./youtube-all-urls-with-domain.csv', index = False)

# %%
white_list = ['twitter.com', 'google.com', 'facebook.com',
              'instagram.com', 'youtube.com', 'youtu.be', 'gmail.com']
filter_df = output[~output['domain'].isin(white_list)]
filter_df.to_csv('./youtube_unique_filtered.csv', index=False)

# %%
filter_df
# Out:
#                                                       url               domain
# 0                   https://mhzacademy.spayee.com/s/store           spayee.com
# 1                     https://forms.gle/T2eexAjR3ypK9DYW8            forms.gle
# 2           https://mhzacademy.com/cpa-marketing-roadmap/       mhzacademy.com
# 4       http://originalroyalty.com/product/aviyah-drea...  originalroyalty.com
# 5       http://originalroyalty.com/product/solomon-the...  originalroyalty.com
# ...                                                   ...                  ...
# 445844                             https://bit.ly/3ya1bDl               bit.ly
# 445845                             https://bit.ly/3ncX5oL               bit.ly
# 445846                             https://bit.ly/3NcsBxz               bit.ly
# 445847                             https://bit.ly/3Ni8IVO               bit.ly
# 445848                             https://bit.ly/3tZNWUp               bit.ly
#
# ...
